# %%
# importing dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sns
from scipy.stats import f_oneway

# %%
# read csv
df  =  pd.read_csv("/content/student-algorizin.csv")
df.head()
# Out:
#   school sex  age address grades funding  linkedin  resume   degree   country  \
# 0     GP   F   18       U    GT3       A         4       4  at_home   teacher
# 1     GP   F   17       U    GT3       T         1       1  at_home     other
# 2     GP   F   15       U    LE3       T         1       1  at_home     other
# 3     GP   F   15       U    GT3       T         4       2   health  services
# 4     GP   F   16       U    GT3       T         3       3    other     other
#
#    ... english technical  behavioral  grit  mentor attend delay  A1  A2   J
# 0  ...       4         3           4     1       1      3     6   5   6   6
# 1  ...       5         3           3     1       1      3     4   5   5   6
# 2  ...       4         3           2     2       3      3    10   7   8  10
# 3  ...       3         2           2     1       1      5     2  15  14  15
# 4  ...       4         3           2     1       2      5     4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# # Data  Cleaning

# %%
# check df shape
df.shape
# Out:
# (395, 33)

# %%
# check datatypes
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# grades        object
# funding       object
# linkedin       int64
# resume         int64
# degree        object
# country       object
# reason        object
# finance       object
# networ         int64
# studytime      int64
# failures       int64
# relocation    object
# settle        object
# visa          object
# stem          object
# cs            object
# intern        object
# intwork       object
# marital       object
# english        int64
# technical      int64
# behavioral     int64
# grit           int64
# mentor         int64
# attend         int64
# delay          int64
# A1             int64
# A2             int64
# J              int64
# dtype: object

# %%
# check the description
df.describe()
# Out:
#               age    linkedin      resume      networ   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#           english   technical  behavioral        grit      mentor      attend  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
# check columns
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'grades', 'funding', 'linkedin',
#        'resume', 'degree', 'country', 'reason', 'finance', 'networ',
#        'studytime', 'failures', 'relocation', 'settle', 'visa', 'stem', 'cs',
#        'intern', 'intwork', 'marital', 'english', 'technical', 'behavioral',
#        'grit', 'mentor', 'attend', 'delay', 'A1', 'A2', 'J'],
#       dtype='object')

# %% [markdown]
# # Chi Square Test

# %%
# making crosstab
#ctab1 = pd.crosstab(df['school'],df['sex'])
# df['sex'],df['address'],df['grades'], df['funding'], df['degree'],df['country'],df['reason'], df['finance'],df['relocation'])
#ctab2 = pd.crosstab( df['settle'], df['visa'],df['stem'],df['cs'],
 #                 df['intern'], df['intwork'], df['marital'])
#, df.address,df.grades, df.funding, df.degree,df.country, df.reason, df.finance,df.relocation, df.settle, df.visa,df.stem.df.cs,
 #                  df.intern, df.intwork, df.marital)
#print(ctab1)
from scipy.stats import chi2_contingency
#chiVal, pVal, df, exp =  chi2_contingency(ctab1)
#print(chiVal, pVal, df, exp)
#ctab2 = pd.crosstab(df['address'],df['grades'])
#print(ctab2)
#chiVal, pVal, df, exp =  chi2_contingency(ctab2)
#print(chiVal, pVal, df, exp)

# %%
# drop 1st row
#df1 = df.iloc[1:,:]
#df1

# %%
# rename column
#print(df1.columns)
#df1 = df1.rename(columns={'student-mat': 'school', 'Unnamed: 1':'sex ', 'Unnamed: 2':'age', 'Unnamed: 3':'address', 'Unnamed: 4':'grades',
       #'Unnamed: 5':'funding ', 'Unnamed: 6':'linkedin', 'Unnamed: 7': 'resume', 'Unnamed: 8':'degree', 'Unnamed: 9':'country',
       #'Unnamed: 10':'reason', 'Unnamed: 11':'finance', 'Unnamed: 12':'networth', 'Unnamed: 13':'studytime',
       #'Unnamed: 14':'failures', 'Unnamed: 15':'relocation', 'Unnamed: 16':'settle', 'Unnamed: 17':'visa',
       #'Unnamed: 18':'stem', 'Unnamed: 19':'cs', 'Unnamed: 20':'intern', 'Unnamed: 21':'intwork',
       #'Unnamed: 22':'marital', 'Unnamed: 23':'english', 'Unnamed: 24':'technical', 'Unnamed: 25':'grit',
       #'Unnamed: 26':'mentor', 'Unnamed: 27':'attend', 'Unnamed: 28':'delay', 'Unnamed: 29':'A1',
      # 'Unnamed: 30':'A2', 'Unnamed: 31':'J', 'Unnamed: 32'}, inplace = True)

# %%
# check null values
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# grades        0
# funding       0
# linkedin      0
# resume        0
# degree        0
# country       0
# reason        0
# finance       0
# networ        0
# studytime     0
# failures      0
# relocation    0
# settle        0
# visa          0
# stem          0
# cs            0
# intern        0
# intwork       0
# marital       0
# english       0
# technical     0
# behavioral    0
# grit          0
# mentor        0
# attend        0
# delay         0
# A1            0
# A2            0
# J             0
# dtype: int64

# %%
# check if target is balanced
df['J'].value_counts()
# Out:
# 10    56
# 11    47
# 0     38
# 15    33
# 8     32
# 13    31
# 12    31
# 9     28
# 14    27
# 16    16
# 6     15
# 18    12
# 7      9
# 5      7
# 17     6
# 19     5
# 20     1
# 4      1
# Name: J, dtype: int64

# %%
# finding unique values
df['school'].unique
# Out:
# <bound method Series.unique of 0      GP
# 1      GP
# 2      GP
# 3      GP
# 4      GP
#        ..
# 390    MS
# 391    MS
# 392    MS
# 393    MS
# 394    MS
# Name: school, Length: 395, dtype: object>

# %%
# get_dummies: convert categorical to numerical
df2 = pd.get_dummies(df)
df2
# Out:
#      age  linkedin  resume  networ  studytime  failures  english  technical  \
# 0     18         4       4       2          2         0        4          3
# 1     17         1       1       1          2         0        5          3
# 2     15         1       1       1          2         3        4          3
# 3     15         4       2       1          3         0        3          2
# 4     16         3       3       1          2         0        4          3
# ..   ...       ...     ...     ...        ...       ...      ...        ...
# 390   20         2       2       1          2         2        5          5
# 391   17         3       1       2          1         0        2          4
# 392   21         1       1       1          1         3        5          5
# 393   18         3       2       3          1         0        4          4
# 394   19         1       1       1          1         0        3          2
#
# ...

# %% [markdown]
# get_dummies creates extra columns, unnecessary

# %%
# check columns
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# grades        object
# funding       object
# linkedin       int64
# resume         int64
# degree        object
# country       object
# reason        object
# finance       object
# networ         int64
# studytime      int64
# failures       int64
# relocation    object
# settle        object
# visa          object
# stem          object
# cs            object
# intern        object
# intwork       object
# marital       object
# english        int64
# technical      int64
# behavioral     int64
# grit           int64
# mentor         int64
# attend         int64
# delay          int64
# A1             int64
# A2             int64
# J              int64
# dtype: object

# %%
# apply Label encoder
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['school'] = label_encoder.fit_transform(df['school'])
df['sex'] = label_encoder.fit_transform(df['sex'])
df['address'] = label_encoder.fit_transform(df['address'])
df['grades'] = label_encoder.fit_transform(df['grades'])
df['funding'] = label_encoder.fit_transform(df['funding'])
df['degree'] = label_encoder.fit_transform(df['degree'])
df['country'] = label_encoder.fit_transform(df['country'])
df['reason'] = label_encoder.fit_transform(df['reason'])
df['finance'] = label_encoder.fit_transform(df['finance'])
df['relocation'] = label_encoder.fit_transform(df['relocation'])
df['settle'] = label_encoder.fit_transform(df['settle'])
df['visa'] = label_encoder.fit_transform(df['visa'])
df['stem'] = label_encoder.fit_transform(df['stem'])
df['cs'] = label_encoder.fit_transform(df['cs'])
df['intern'] = label_encoder.fit_transform(df['intern'])
df['intwork'] = label_encoder.fit_transform(df['intwork'])
df['marital'] = label_encoder.fit_transform(df['marital'])
df
# Out:
#      school  sex  age  address  grades  funding  linkedin  resume  degree  \
# 0         0    0   18        1       0        0         4       4       0
# 1         0    0   17        1       0        1         1       1       0
# 2         0    0   15        1       1        1         1       1       0
# 3         0    0   15        1       0        1         4       2       1
# 4         0    0   16        1       0        1         3       3       2
# ..      ...  ...  ...      ...     ...      ...       ...     ...     ...
# 390       1    1   20        1       1        0         2       2       3
# 391       1    1   17        1       1        1         3       1       3
# 392       1    1   21        0       0        1         1       1       2
# 393       1    1   18        0       1        1         3       2       3
# 394       1    1   19        1       1        1         1       1       2
#
#      country  ...  english  technical  behavioral  grit  mentor  attend  \
# ...

# %%
# check conversion
df.dtypes
# Out:
# school        int64
# sex           int64
# age           int64
# address       int64
# grades        int64
# funding       int64
# linkedin      int64
# resume        int64
# degree        int64
# country       int64
# reason        int64
# finance       int64
# networ        int64
# studytime     int64
# failures      int64
# relocation    int64
# settle        int64
# visa          int64
# stem          int64
# cs            int64
# intern        int64
# intwork       int64
# marital       int64
# english       int64
# technical     int64
# behavioral    int64
# grit          int64
# mentor        int64
# attend        int64
# delay         int64
# A1            int64
# A2            int64
# J             int64
# dtype: object

# %% [markdown]
# # Data Exploration

# %% [markdown]
# # ANOVA

# %%
# ANOVA test for checking F-value, P-value
from scipy.stats import f_oneway
# conduct the one-way ANOVA
f_oneway(df['school'],df['sex'],df['age'],df['address'],df['grades'],df['funding'],df['linkedin'],df['resume'],
         df['degree'],df['country'],df['reason'],df['finance'],df['networ'],df['studytime'],df['failures'],
         df['relocation'],df['settle'],df['visa'],df['stem'],df['cs'],df['intern'],df['intwork'],df['marital'],
         df['english'],df['technical'],df['behavioral'],df['grit'],df['mentor'],df['attend'],df['delay'],df['A1'],df['A2'],df['J'])
# Out:
# F_onewayResult(statistic=1489.4515536282336, pvalue=0.0)

# %% [markdown]
# # Correlation test

# %%
df.corr()
# Out:
#               school       sex       age   address    grades   funding  \
# school      1.000000 -0.012286  0.377610 -0.279797  0.064866  0.045923
# sex        -0.012286  1.000000 -0.028606 -0.028504  0.089862  0.023443
# age         0.377610 -0.028606  1.000000 -0.146722  0.037847  0.029598
# address    -0.279797 -0.028504 -0.146722  1.000000  0.072472 -0.042572
# grades      0.064866  0.089862  0.037847  0.072472  1.000000 -0.149612
# funding     0.045923  0.023443  0.029598 -0.042572 -0.149612  1.000000
# linkedin   -0.133333  0.078228 -0.163658  0.138804 -0.043068 -0.123565
# resume     -0.079807  0.034878 -0.163438  0.072178 -0.058879 -0.088730
# degree     -0.056670  0.191421 -0.069104  0.108818  0.071386 -0.054476
# country     0.018974  0.084957 -0.035191 -0.001911 -0.084448  0.033892
# reason     -0.090010 -0.095867 -0.015337 -0.047891 -0.019212 -0.003553
# finance     0.011109 -0.071343  0.290485 -0.044512 -0.002718 -0.108715
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.corr(),annot=True)

# %%
# Create correlation matrix
corr_mat = df.corr(method='pearson')
# Retain upper triangular values of correlation matrix and
# make Lower triangular values Null
upper_corr_mat = corr_mat.where(
    np.triu(np.ones(corr_mat.shape), k=1).astype(np.bool))
  
# Convert to 1-D series and drop Null values
unique_corr_pairs = upper_corr_mat.unstack().dropna()
  
# Sort correlation pairs
sorted_mat = unique_corr_pairs.sort_values()
print(sorted_mat)
# Out:
# J          failures   -0.360415
# A2         failures   -0.355896
# A1         failures   -0.354718
# networ     address    -0.328096
# studytime  sex        -0.306268
#                          ...
# resume     linkedin    0.623455
# mentor     grit        0.647544
# J          A1          0.801468
# A2         A1          0.852118
# J          A2          0.904868
# Length: 528, dtype: float64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   import sys

# %% [markdown]
# # Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = df.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(df.values, i)
                          for i in range(len(df.columns))]
  
print(vif_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#        feature        VIF
# 0       school   1.560434
# 1          sex   2.748875
# 2          age  94.244018
# 3      address   5.806451
# 4       grades   1.582014
# 5      funding  10.665313
# 6     linkedin  16.131143
# 7       resume  11.977220
# 8       degree   6.007771
# 9      country   9.005279
# 10      reason   2.341776
# 11     finance   4.308160
# 12      networ   6.412124
# 13   studytime   9.153319
# 14    failures   1.699861
# 15  relocation   1.327093
# 16      settle   3.268409
# 17        visa   2.392312
# 18        stem   2.323951
# 19          cs   5.376265
# 20      intern  21.877657
# 21     intwork   7.174459
# 22     marital   1.728020
# 23     english  22.961681
# 24   technical  14.333373
# 25  behavioral  12.760979
# ...

# %%
print('school:',df['J'].corr(df['school']))
print('sex:',df['J'].corr(df['sex']))
print('age:',df['J'].corr(df['age']))
print('address:',df['J'].corr(df['address']))
print('grades:',df['J'].corr(df['grades']))
print('funding:',df['J'].corr(df['funding']))
print('linkedin:',df['J'].corr(df['linkedin']))
print('resume:',df['J'].corr(df['resume']))
print('degree:',df['J'].corr(df['degree']))
print('country:',df['J'].corr(df['country']))
print('reason:',df['J'].corr(df['reason']))
print('finance:',df['J'].corr(df['finance']))
print('networ:',df['J'].corr(df['networ']))
print('studytime:',df['J'].corr(df['studytime']))
print('failures:',df['J'].corr(df['failures']))
print('relocation:',df['J'].corr(df['relocation']))
print('settle:',df['J'].corr(df['settle']))
print('visa:',df['J'].corr(df['visa']))
print('stem:',df['J'].corr(df['stem']))
print('cs:',df['J'].corr(df['cs']))
print('intern:',df['J'].corr(df['intern']))
print('intwork:',df['J'].corr(df['intwork']))
print('marital:',df['J'].corr(df['marital']))
print('english:',df['J'].corr(df['english']))
print('technial:',df['J'].corr(df['technical']))
print('behavioral:',df['J'].corr(df['behavioral']))
print('grit:',df['J'].corr(df['grit']))
print('mentor:',df['J'].corr(df['mentor']))
print('attend:',df['J'].corr(df['attend']))
print('delay:',df['J'].corr(df['delay']))
print('A1:',df['J'].corr(df['A1']))
print('A2:',df['J'].corr(df['A2']))
# Out:
# school: -0.04501694311330678
# sex: 0.10345564746639291
# age: -0.16157943813834058
# address: 0.10575606393084076
# grades: 0.08140710977255437
# funding: -0.058008984959311186
# linkedin: 0.21714749613860598
# resume: 0.15245693890425902
# degree: 0.10208179585171823
# country: 0.042285872548906506
# reason: 0.12199410591813471
# finance: -0.0701091004372676
# networ: -0.117142052816149
# studytime: 0.09781968965319626
# failures: -0.3604149404616497
# relocation: -0.08278821499316329
# settle: -0.03915714523790471
# visa: 0.10199624071669922
# stem: 0.01609970129581448
# cs: 0.051567900910917536
# intern: 0.18246461785815765
# intwork: 0.09848337126072887
# marital: -0.12996995016344978
# english: 0.05136342888128215
# technial: 0.011307240308313026
# behavioral: -0.13279147350332923
# grit: -0.05466004056673597
# mentor: -0.05193932374224616
# attend: -0.06133460487712137
# delay: 0.03424731615006931
# A1: 0.8014679320174146
# A2: 0.9048679892693009

# %% [markdown]
# # A1, A2 are strongly positively correlated with J

# %% [markdown]
# # Chi Square Test

# %%
from scipy.stats import chi2_contingency
data = [[df['school'],df['sex']]]
stat, p, dof, expected = chi2_contingency(data)
print(stat, p, dof, expected)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-5ccf9ec38edc> in <module>()
#       1 from scipy.stats import chi2_contingency
#       2 data = [[df['school'],df['sex']]]
# ----> 3 stat, p, dof, expected = chi2_contingency(data)
#       4 print(stat, p, dof, expected)
#
# /usr/local/lib/python3.7/dist-packages/scipy/stats/contingency.py in chi2_contingency(observed, correction, lambda_)
#     253         zeropos = list(zip(*np.nonzero(expected == 0)))[0]
#     254         raise ValueError("The internally computed table of expected "
# --> 255                          "frequencies has a zero element at %s." % (zeropos,))
#     256
#     257     # The degrees of freedom
#
# ValueError: The internally computed table of expected frequencies has a zero element at (0, 0, 0).

# %%
# split the data
y = df.iloc[:,32]
x = df.iloc[:,:32]
x
# Out:
#      school  sex  age  address  grades  funding  linkedin  resume  degree  \
# 0         0    0   18        1       0        0         4       4       0
# 1         0    0   17        1       0        1         1       1       0
# 2         0    0   15        1       1        1         1       1       0
# 3         0    0   15        1       0        1         4       2       1
# 4         0    0   16        1       0        1         3       3       2
# ..      ...  ...  ...      ...     ...      ...       ...     ...     ...
# 390       1    1   20        1       1        0         2       2       3
# 391       1    1   17        1       1        1         3       1       3
# 392       1    1   21        0       0        1         1       1       2
# 393       1    1   18        0       1        1         3       2       3
# 394       1    1   19        1       1        1         1       1       2
#
#      country  ...  marital  english  technical  behavioral  grit  mentor  \
# ...

# %%
y
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 390     9
# 391    16
# 392     7
# 393    10
# 394     9
# Name: J, Length: 395, dtype: int64

# %%
# splitting the dataset into training and test set
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 47)

# %%
x_train
# Out:
#      school  sex  age  address  grades  funding  linkedin  resume  degree  \
# 300       0    0   18        1       1        0         4       4       1
# 303       0    0   17        1       0        1         3       2       1
# 10        0    0   15        1       0        1         4       4       4
# 40        0    0   16        1       1        1         2       2       2
# 302       0    0   17        1       0        1         4       2       2
# ..      ...  ...  ...      ...     ...      ...       ...     ...     ...
# 72        0    0   15        0       0        1         1       1       2
# 264       0    0   18        1       0        1         2       2       0
# 327       0    1   17        0       0        1         2       2       3
# 390       1    1   20        1       1        0         2       2       3
# 135       0    0   15        1       0        1         4       4       3
#
#      country  ...  marital  english  technical  behavioral  grit  mentor  \
# ...

# %%
y_train
# Out:
# 300    11
# 303    18
# 10      9
# 40     11
# 302    14
#        ..
# 72      5
# 264     0
# 327    10
# 390     9
# 135     0
# Name: J, Length: 296, dtype: int64

# %% [markdown]
# # Feature Engineering
#
# # Applying Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)
x_train
# Out:
# array([[-0.36023741, -0.92195445,  1.0213713 , ...,  0.95691686,
#          0.35825648, -0.16251913],
#        [-0.36023741, -0.92195445,  0.24016741, ..., -0.7305144 ,
#          1.85183281,  1.64790901],
#        [-0.36023741, -0.92195445, -1.32224037, ..., -0.7305144 ,
#         -0.23917405, -0.67978431],
#        ...,
#        [-0.36023741,  1.08465229,  0.24016741, ...,  0.23373203,
#          0.05954122, -0.16251913],
#        [ 2.77594711,  1.08465229,  2.58377909, ...,  0.59532445,
#         -0.53788931, -0.42115172],
#        [-0.36023741, -0.92195445, -1.32224037, ..., -0.7305144 ,
#          0.05954122, -2.74884503]])

# %%
x_train.size
# Out:
# 9472

# %%
y_train.size
# Out:
# 296

# %%
# visualize the data
plt.scatter(x_train, y_train, label='Training data', color='r', alpha=0.7) 
plt.scatter(x_test, y_test, label='Test data', color='r', alpha=0.7) 
plt.legend()
plt.title('Train-Test Data')
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-179-1ed7ef96abf5> in <module>()
#       1 # visualize the data
# ----> 2 plt.scatter(x_train, y_train, label='Training data', color='r', alpha=0.7)
#       3 plt.scatter(x_test, y_test, label='Test data', color='r', alpha=0.7)
#       4 plt.legend()
#       5 plt.title('Train-Test Data')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
# reshape the data
#x_train = x_train.reshape((-1,1))
#x_test = x_test.reshape((-1,1))
#x_train
# Out:
# array([[-0.36023741],
#        [-0.92195445],
#        [ 1.0213713 ],
#        ...,
#        [-0.7305144 ],
#        [ 0.05954122],
#        [-2.74884503]])

# %%
y_train
# Out:
# 300    11
# 303    18
# 10      9
# 40     11
# 302    14
#        ..
# 72      5
# 264     0
# 327    10
# 390     9
# 135     0
# Name: J, Length: 296, dtype: int64

# %%
# converting to array
#y_train = y_train.to_numpy()
#y_train
# Out:
# array([11, 18,  9, 11, 14, 10,  9, 17, 12, 16, 10, 18, 11,  8, 14,  0, 11,
#        15,  0, 13, 14, 11,  9, 10,  0,  9, 10,  0, 18, 10, 10,  9,  9,  6,
#        10, 12, 20,  7,  8, 14, 16, 18, 10,  6, 18, 10, 10, 16, 12, 14, 11,
#        19,  7, 11,  6, 18, 13, 15, 15, 18, 12, 10, 11, 15,  9, 14, 16, 13,
#        11, 11, 13, 11,  7, 13, 10,  0, 10, 15, 15, 10,  6,  0, 11,  6,  9,
#        10,  7, 13, 11, 10,  9, 11, 15, 10, 10, 13, 16, 15, 14, 10,  6,  7,
#        14, 11,  0, 14, 15, 10,  5, 10, 13,  6, 11, 12, 17, 12, 10,  5, 12,
#        16, 17, 17, 11,  0,  8, 10, 11,  8, 15, 13, 15,  0, 10, 13,  8,  8,
#        14,  9,  5,  0,  0, 15, 11, 12,  6,  8, 10, 13,  8,  8, 18,  8,  8,
#         8,  9,  0,  9,  8, 10, 16,  6, 14, 10, 12, 18, 10, 13, 18, 14, 10,
#         9,  9, 11,  9, 10, 11, 13, 19, 10,  8, 11, 11, 10, 15, 10, 10, 11,
#         0,  9,  8,  0, 16,  5,  0, 16,  6, 12,  6, 11,  0, 12, 10, 19, 12,
# ...

# %%
# converting to array
#y_test= y_test.to_numpy()
#y_test
# Out:
# array([10, 16, 11,  5, 11, 15,  8, 14,  9, 14, 13, 11, 12,  0,  0, 12, 13,
#        15, 16, 11, 18, 15,  9, 16, 12, 15, 11, 12, 14,  8, 15, 17,  0, 12,
#        13, 15, 16, 11, 12,  0, 14, 16, 11, 15, 11, 10, 10,  8, 12,  0,  8,
#        12, 12,  8, 11,  8, 13, 13,  0,  8, 13, 11,  9, 11, 15,  0, 10,  0,
#         8, 12, 15, 10, 13,  0, 10, 10, 11, 19,  6,  8, 11, 11, 15, 12,  9,
#        12, 16, 13, 11, 10,  0,  8, 14,  0, 13,  8,  0,  8,  6])

# %% [markdown]
# # Applying Linear Regression

# %%
# fitting multiple linear regression to the training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the test set results
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([10.31361962, 15.29564425, 10.66831761,  1.75224241, 10.034025  ,
#        16.51040301,  8.14398737, 13.96717451,  8.41916097, 14.39919946,
#        13.0913418 ,  9.75799097, 12.34998539, -2.67193215,  3.46268385,
#        12.62723527, 13.89345247, 16.00529093, 14.80867889, 13.59991282,
#        18.66001848, 14.44497194,  8.21568084, 16.90779019, 11.57791847,
#        15.73179437,  9.10370108,  8.91218018, 14.480248  ,  7.11271581,
#        16.81790086, 16.53301139,  8.22535054, 12.09848322, 12.71407954,
#        15.40964496, 17.67403481,  8.89198892, 10.97773579,  6.3425923 ,
#        12.67863083, 16.46140505, 10.17233457, 15.01017513, 11.77958215,
#         8.78814313,  9.95723811,  5.45160482, 10.18884804,  7.69598975,
#         7.10756201, 11.56773074, 11.39597318,  9.91540766, 11.28355605,
#         6.48160882, 11.95949753, 12.33355975,  7.04642648,  7.13292943,
#        11.28881406, 10.84305044,  5.52449361, 12.41671862, 15.16194069,
# ...

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred)
print('R2-Score: ', score)
# Out:
# R2-Score:  0.7340775498226499

# %%
# Model evaluation using Mean Square Error (MSE)
from sklearn import metrics
print('Mean Square Error: ', metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Square Error:  5.857348269481347

# %%
# Model evaluation using Root mean square error
print('Root Mean Square Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Root Mean Square Error:  2.42019591551621

# %%
# Model Evaluation using Mean Absolute error
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error:  1.6034898879637265

# %% [markdown]
# # Naive Bayes Regressor

# %%
from sklearn.linear_model import BayesianRidge
model = BayesianRidge()
model.fit(x_train, y_train)
# Out:
# BayesianRidge()

# %%
# Predicting the test set results
y_pred_nb = regressor.predict(x_test)
y_pred_nb
# Out:
# array([10.31361962, 15.29564425, 10.66831761,  1.75224241, 10.034025  ,
#        16.51040301,  8.14398737, 13.96717451,  8.41916097, 14.39919946,
#        13.0913418 ,  9.75799097, 12.34998539, -2.67193215,  3.46268385,
#        12.62723527, 13.89345247, 16.00529093, 14.80867889, 13.59991282,
#        18.66001848, 14.44497194,  8.21568084, 16.90779019, 11.57791847,
#        15.73179437,  9.10370108,  8.91218018, 14.480248  ,  7.11271581,
#        16.81790086, 16.53301139,  8.22535054, 12.09848322, 12.71407954,
#        15.40964496, 17.67403481,  8.89198892, 10.97773579,  6.3425923 ,
#        12.67863083, 16.46140505, 10.17233457, 15.01017513, 11.77958215,
#         8.78814313,  9.95723811,  5.45160482, 10.18884804,  7.69598975,
#         7.10756201, 11.56773074, 11.39597318,  9.91540766, 11.28355605,
#         6.48160882, 11.95949753, 12.33355975,  7.04642648,  7.13292943,
#        11.28881406, 10.84305044,  5.52449361, 12.41671862, 15.16194069,
# ...

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, y_pred_nb)
print('R2-Score: ', score)
# Out:
# R2-Score:  0.7340775498226499

# %%
# Model evaluation using Mean Square Error (MSE)
from sklearn import metrics
print('Mean Square Error: ', metrics.mean_squared_error(y_test, y_pred_nb))
# Out:
# Mean Square Error:  5.857348269481347

# %%
# Model evaluation using Root mean square error
print('Root Mean Square Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred_nb)))
# Out:
# Root Mean Square Error:  2.42019591551621

# %%
# Model Evaluation using Mean Absolute error
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred_nb))
# Out:
# Mean Absolute Error:  1.6034898879637265

# %% [markdown]
# # Support Vector Regressor with Linear kernel

# %%
from sklearn.svm import SVR 
svr_linear = SVR(kernel = 'linear', gamma='scale', C=1.0, epsilon=0.1)
svr_linear.fit(x_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
# predict J from test dataset
y_pred_svr_lin = svr_linear.predict((x_test))
y_pred_svr_lin
# Out:
# array([10.78513903, 15.29103557, 10.62208615,  3.54584014, 10.58719739,
#        15.48481295,  8.26682845, 14.03307323,  8.51248238, 14.22892085,
#        12.72346159, 10.77405576, 11.80504251, -1.76695087,  4.74140807,
#        12.74606379, 13.15207701, 15.35884125, 15.26066706, 12.8664171 ,
#        18.67606567, 14.1421989 ,  8.45094348, 16.43647984, 11.8845248 ,
#        15.20625889,  9.47675382,  9.55119435, 14.22228167,  7.27843483,
#        16.43021482, 16.37692561,  9.59012067, 11.87885458, 12.88082692,
#        15.45684116, 16.68371629,  9.35530291, 10.80695604,  7.23873628,
#        13.14557517, 16.37713786,  9.71475956, 15.08332772, 10.79306233,
#         9.49174858,  9.65391925,  5.97840397, 10.57605408,  8.47903501,
#         7.32931457, 11.99987612, 11.96212583,  8.6462987 , 10.63570966,
#         7.08332136, 12.6694886 , 12.83985467,  8.3967404 ,  8.32538027,
#        12.53388605, 10.63563451,  6.87137948, 11.96733435, 15.20205351,
# ...

# %% [markdown]
# # Model Evaluation

# %%
score = r2_score(y_test, y_pred_svr_lin)
print('R2-Score: ', score)
# Out:
# R2-Score:  0.720038069941443

# %%
# Model evaluation using Mean Square Error (MSE)
from sklearn import metrics
print('Mean Square Error: ', metrics.mean_squared_error(y_test, y_pred_svr_lin))
# Out:
# Mean Square Error:  6.166589264860872

# %%
# Model evaluation using Root mean square error
print('Root Mean Square Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred_svr_lin)))
# Out:
# Root Mean Square Error:  2.4832618196357936

# %%
# Model Evaluation using Mean Absolute error
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred_svr_lin))
# Out:
# Mean Absolute Error:  1.414600761525327

# %% [markdown]
# # Support Vector Regressor - RBF

# %%
svr_rbf = SVR(kernel='rbf', gamma='scale', C=5.0, epsilon=0.5)
svr_rbf.fit(x_train, y_train)
# Out:
# SVR(C=5.0, epsilon=0.5)

# %%
# predict J from test dataset
y_pred_svr_rbf = svr_linear.predict((x_test))
y_pred_svr_rbf
# Out:
# array([10.78513903, 15.29103557, 10.62208615,  3.54584014, 10.58719739,
#        15.48481295,  8.26682845, 14.03307323,  8.51248238, 14.22892085,
#        12.72346159, 10.77405576, 11.80504251, -1.76695087,  4.74140807,
#        12.74606379, 13.15207701, 15.35884125, 15.26066706, 12.8664171 ,
#        18.67606567, 14.1421989 ,  8.45094348, 16.43647984, 11.8845248 ,
#        15.20625889,  9.47675382,  9.55119435, 14.22228167,  7.27843483,
#        16.43021482, 16.37692561,  9.59012067, 11.87885458, 12.88082692,
#        15.45684116, 16.68371629,  9.35530291, 10.80695604,  7.23873628,
#        13.14557517, 16.37713786,  9.71475956, 15.08332772, 10.79306233,
#         9.49174858,  9.65391925,  5.97840397, 10.57605408,  8.47903501,
#         7.32931457, 11.99987612, 11.96212583,  8.6462987 , 10.63570966,
#         7.08332136, 12.6694886 , 12.83985467,  8.3967404 ,  8.32538027,
#        12.53388605, 10.63563451,  6.87137948, 11.96733435, 15.20205351,
# ...

# %% [markdown]
# # Model Evaluation

# %%
score = r2_score(y_test, y_pred_svr_rbf)
print('R2-Score: ', score)
# Out:
# R2-Score:  0.720038069941443

# %%
# Model evaluation using Mean Square Error (MSE)
from sklearn import metrics
print('Mean Square Error: ', metrics.mean_squared_error(y_test, y_pred_svr_rbf))
# Out:
# Mean Square Error:  6.166589264860872

# %%
# Model evaluation using Root mean square error
print('Root Mean Square Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred_svr_rbf)))
# Out:
# Root Mean Square Error:  2.4832618196357936

# %%
# Model Evaluation using Mean Absolute error
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred_svr_rbf))
# Out:
# Mean Absolute Error:  1.414600761525327

# %% [markdown]
# # KNN Regressor

# %%
# searching for best hyperparemeter
from sklearn import neighbors
from sklearn.model_selection import GridSearchCV
params = {'n_neighbors':[2,3,4,5,6,7,8,9]}

knn = neighbors.KNeighborsRegressor()

model1 = GridSearchCV(knn, params, cv=5)
model1.fit(x_train, y_train)
model1.best_params_
# Out:
# {'n_neighbors': 6}

# %%
knn_best = neighbors.KNeighborsRegressor(n_neighbors = 6)
knn_best.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=6)

# %%
# predict J from test dataset
y_pred_knn_best = knn_best.predict((x_test))
y_pred_knn_best
# Out:
# array([12.16666667, 15.16666667, 10.        ,  5.16666667, 11.83333333,
#        14.16666667,  9.33333333, 12.16666667, 11.33333333, 12.66666667,
#        10.66666667,  9.33333333,  8.16666667,  4.33333333,  5.5       ,
#        11.        ,  9.5       , 12.66666667, 12.16666667, 13.33333333,
#        16.83333333, 15.66666667, 10.16666667, 15.        , 10.5       ,
#        14.        ,  9.5       , 11.        , 13.83333333,  8.83333333,
#        14.83333333, 12.83333333, 10.66666667,  8.83333333, 10.5       ,
#        14.16666667, 13.66666667,  7.66666667, 10.83333333,  5.16666667,
#        14.16666667, 14.66666667,  8.66666667, 11.5       , 11.16666667,
#         8.5       , 11.66666667,  7.33333333, 11.5       , 11.83333333,
#        10.33333333, 10.33333333,  8.83333333,  9.        ,  9.5       ,
#         9.5       ,  9.33333333, 10.16666667,  7.66666667,  6.5       ,
#         9.66666667,  7.83333333,  5.33333333, 13.        , 12.66666667,
# ...

# %% [markdown]
# # Model Evaluation

# %%
score = r2_score(y_test, y_pred_knn_best)
print('R2-Score: ', score)
# Out:
# R2-Score:  0.48020793766965286

# %%
# Model evaluation using Mean Square Error (MSE)
from sklearn import metrics
print('Mean Square Error: ', metrics.mean_squared_error(y_test, y_pred_knn_best))
# Out:
# Mean Square Error:  11.449214365881033

# %%
# Model evaluation using Root mean square error
print('Root Mean Square Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred_knn_best)))
# Out:
# Root Mean Square Error:  3.383668773074728

# %%
# Model Evaluation using Mean Absolute error
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred_knn_best))
# Out:
# Mean Absolute Error:  2.4124579124579126

# %% [markdown]
# # Random Forest Regressor

# %%
from pandas.core.common import random_state
from sklearn.ensemble import RandomForestRegressor
# create a random forest object
rf = RandomForestRegressor(n_estimators = 200, random_state= 47)
# fit the model with training set
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=47)

# %%
# predict J from test dataset
y_pred_rf = rf.predict((x_test))
y_pred_rf
# Out:
# array([10.85 , 15.55 , 10.64 ,  5.595, 10.475, 15.285,  7.73 , 13.905,
#         8.69 , 13.875, 13.215, 10.555, 11.615,  0.5  ,  0.11 , 13.33 ,
#        13.715, 15.115, 15.45 , 12.75 , 18.445, 14.21 ,  8.27 , 16.73 ,
#        12.125, 15.29 ,  9.13 ,  9.32 , 13.82 ,  7.16 , 16.43 , 16.07 ,
#         9.16 , 11.8  , 13.06 , 15.33 , 16.19 ,  8.775, 11.13 ,  1.735,
#        13.785, 16.105, 10.56 , 15.59 , 11.665,  9.31 ,  9.845,  1.505,
#        10.565,  5.8  ,  6.895, 12.695, 12.915,  7.41 , 10.475,  7.595,
#        13.47 , 13.65 ,  3.92 ,  3.775, 12.775, 11.035,  7.385, 12.135,
#        15.535,  1.585,  9.695,  5.635,  6.3  , 12.315, 13.815,  8.125,
#        13.105,  2.39 ,  7.06 ,  9.84 ,  1.54 , 18.625,  5.69 ,  7.255,
#        11.585, 11.865, 14.005, 11.47 ,  8.505, 12.22 , 15.67 , 11.71 ,
#        10.6  ,  9.89 ,  0.025,  6.895, 13.935,  0.   , 14.055,  5.445,
#         0.18 ,  5.91 ,  1.505])

# %% [markdown]
# # Model Evaluation

# %%
# Model Evaluation using R2 score
score = r2_score(y_test, y_pred_rf)
print('R2-Score: ', score)
# Out:
# R2-Score:  0.8058980315635393

# %%
# Model evaluation using Mean Square Error (MSE)
from sklearn import metrics
print('Mean Square Error: ', metrics.mean_squared_error(y_test, y_pred_rf))
# Out:
# Mean Square Error:  4.275392424242424

# %%
# Model evaluation using Root mean square error
print('Root Mean Square Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred_rf)))
# Out:
# Root Mean Square Error:  2.0677022087917845

# %%
# Model Evaluation using Mean Absolute error
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred_rf))
# Out:
# Mean Absolute Error:  1.1707070707070708

# %% [markdown]
# # Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor 

dt = DecisionTreeRegressor(random_state = 47)

# fit the decision tree with training data

dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=47)

# %%
# predict J from test dataset
y_pred_dt = dt.predict((x_test))
y_pred_dt
# Out:
# array([10., 15., 11.,  4.,  9., 16.,  6., 13.,  8., 15., 14., 10., 11.,
#         0.,  0., 13., 13., 14., 16., 13., 20., 15., 10., 18., 12., 14.,
#         8.,  8., 14.,  7., 18., 17.,  9., 11., 13., 15., 15., 11., 10.,
#         0., 14., 16., 12., 17., 11., 10., 11.,  0.,  9.,  9.,  6., 13.,
#        14., 10.,  9.,  7., 13., 13.,  0.,  0., 12., 11.,  8., 11., 15.,
#         0., 11.,  9.,  4., 10., 14.,  8., 12.,  0.,  8.,  9.,  0., 19.,
#         6.,  8., 11., 10., 14., 10.,  8., 12., 16., 13., 12., 10.,  0.,
#         8., 13.,  0., 14.,  4.,  0.,  5.,  0.])

# %% [markdown]
# # Model Evaluation

# %%
# Model Evaluation using R2 score
score = r2_score(y_test, y_pred_dt)
print('R2-Score: ', score)
# Out:
# R2-Score:  0.677156965379235

# %%
# Model evaluation using Mean Square Error (MSE)
from sklearn import metrics
print('Mean Square Error: ', metrics.mean_squared_error(y_test, y_pred_dt))
# Out:
# Mean Square Error:  7.111111111111111

# %%
# Model evaluation using Root mean square error
print('Root Mean Square Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred_dt)))
# Out:
# Root Mean Square Error:  2.6666666666666665

# %%
# Model Evaluation using Mean Absolute error
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred_dt))
# Out:
# Mean Absolute Error:  1.4747474747474747

# %% [markdown]
# # XGBOOST Regressor

# %%
# finding best hyperparameter
from xgboost import XGBRegressor
xgb_r = XGBRegressor()
params = {
    'n_estimators': [400, 700, 1000],
    'colsample_bytree': [0.7, 0.8],
    'max_depth': [15,20,25],
    'reg_alpha': [1.1,1.2,1.3],
    'subsample':[0.7,0.8,0.9]
}
model2 = GridSearchCV(xgb_r, params, cv=5)
model2.fit(x_train, y_train)
model2.best_params_
# Out:
# [02:02:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:02:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:02:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:02:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:02:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:02:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:02:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# ...

# %%
xgb_best = XGBRegressor(max_depth=15,n_estimator=400,reg_alpha=1.1, subsample=0.8, learning_rate=0.1, objective='reg:linear', booster='gbtree')
xgb_best.fit(x_train, y_train)
# Out:
# [02:12:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(max_depth=15, n_estimator=400, reg_alpha=1.1, subsample=0.8)

# %%
y_pred_xgb = xgb_best.predict(x_test)
y_pred_xgb
# Out:
# array([10.607408  , 15.65394   , 10.953232  ,  5.612986  ,  9.8089    ,
#        15.665911  ,  8.936665  , 13.967913  ,  8.970014  , 14.445288  ,
#        12.319412  , 10.932471  , 11.808891  ,  1.9326717 , -0.18873054,
#        12.959178  , 13.420766  , 15.122849  , 14.438302  , 13.009812  ,
#        18.232403  , 14.610363  ,  9.659505  , 16.41293   , 12.59266   ,
#        15.736849  ,  8.855359  ,  9.528608  , 14.595064  ,  7.2299924 ,
#        16.444798  , 15.914868  ,  6.2438617 , 11.505427  , 12.960107  ,
#        16.021122  , 16.163635  ,  8.299652  , 11.804313  , -1.1447945 ,
#        13.827088  , 16.14325   , 10.434303  , 14.983364  , 11.561221  ,
#         9.992736  , 10.622022  ,  1.2424172 , 10.836953  ,  2.831188  ,
#         7.648902  , 12.697727  , 12.003684  ,  7.340906  , 10.067798  ,
#         6.1207514 , 12.723922  , 12.93464   ,  2.4122062 ,  1.6670517 ,
#        11.3195095 , 11.0471525 ,  6.8991714 , 12.593928  , 15.378196  ,
# ...

# %% [markdown]
# # Model Evaluation

# %%
# Model Evaluation using R2 score
score = r2_score(y_test, y_pred_xgb)
print('R2-Score: ', score)
# Out:
# R2-Score:  0.8264525131210407

# %%
# Model evaluation using Mean Square Error (MSE)
from sklearn import metrics
print('Mean Square Error: ', metrics.mean_squared_error(y_test, y_pred_xgb))
# Out:
# Mean Square Error:  3.822648562636821

# %%
# Model evaluation using Root mean square error
print('Root Mean Square Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_pred_xgb)))
# Out:
# Root Mean Square Error:  1.9551594724310397

# %%
# Model Evaluation using Mean Absolute error
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred_xgb))
# Out:
# Mean Absolute Error:  1.157339177348397

# %% [markdown]
# # Regression with AutoML

# %%
# !pip3 install h2o --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 177.0 MB 39 kB/s
# ...
#   Created wheel for h2o: filename=h2o-3.36.1.2-py2.py3-none-any.whl size=177070945 sha256=bf6188d8832e9dc66059d6ea6cfa8d46612487e2fa52ae860baca25aef26a3dc
#   Stored in directory: /root/.cache/pip/wheels/a5/2b/ae/534595df09001e1573b1046be62a3f049507307340119db65c
# Successfully built h2o
# ...

# %%
import h2o
from h2o.automl import H2OAutoML
print(h2o.__version__)
# Out:
# 3.36.1.2

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.15" 2022-04-19; OpenJDK Runtime Environment (build 11.0.15+10-Ubuntu-0ubuntu0.18.04.1); OpenJDK 64-Bit Server VM (build 11.0.15+10-Ubuntu-0ubuntu0.18.04.1, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.7/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmp5t70nxj6
#   JVM stdout: /tmp/tmp5t70nxj6/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmp5t70nxj6/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         05 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.36.1.2
# ...

# %%
# Load data into H2O
df_auto = h2o.import_file("/content/student-algorizin.csv")
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
#Splitting the dataset into train and test datasets
splits = df_auto.split_frame(ratios=[0.8],seed=1)
train = splits[0]
test = splits[1]

# %%
#Specifying the Response and Predictor variables
y_auto = "J" 
x = df_auto.columns 
x.remove(y_auto)

# %%
aml = H2OAutoML(max_runtime_secs=120, verbosity="info")        
aml.train(x=x,y=y_auto, training_frame=train)
# Out:
# AutoML progress: |
# 02:19:31.85: Project: AutoML_1_20220630_21930
# 02:19:31.118: 5-fold cross-validation will be used.
# 02:19:31.119: Setting stopping tolerance adaptively based on the training frame: 0.05
# 02:19:31.119: Build control seed: -1 (random)
# 02:19:31.120: training frame: Frame key: AutoML_1_20220630_21930_training_py_2_sid_9f31    cols: 33    rows: 316  chunks: 1    size: 19546  checksum: -4283023934712
# 02:19:31.123: validation frame: NULL
# 02:19:31.124: leaderboard frame: NULL
# 02:19:31.124: blending frame: NULL
# 02:19:31.124: response column: J
# 02:19:31.124: fold column: null
# 02:19:31.125: weights column: null
# ...

# %%
lb = aml.leaderboard
lb.head()
# Out:
# <table>
# <thead>
# <tr><th>model_id                                              </th><th style="text-align: right;">   rmse</th><th style="text-align: right;">    mse</th><th style="text-align: right;">    mae</th><th style="text-align: right;">     rmsle</th><th style="text-align: right;">  mean_residual_deviance</th></tr>
# </thead>
# <tbody>
# <tr><td>XGBoost_grid_1_AutoML_1_20220630_21930_model_3        </td><td style="text-align: right;">1.58795</td><td style="text-align: right;">2.52159</td><td style="text-align: right;">1.09403</td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 2.52159</td></tr>
# <tr><td>StackedEnsemble_BestOfFamily_4_AutoML_1_20220630_21930</td><td style="text-align: right;">1.59124</td><td style="text-align: right;">2.53204</td><td style="text-align: right;">1.08108</td><td style="text-align: right;">nan       </td><td style="text-align: right;">                 2.53204</td></tr>
# ...

# %%
# Get model ids for all models in the AutoML Leaderboard
model_ids = list(aml.leaderboard['model_id'].as_data_frame().iloc[:,0])
model_ids
# Out:
# ['XGBoost_grid_1_AutoML_1_20220630_21930_model_3',
#  'StackedEnsemble_BestOfFamily_4_AutoML_1_20220630_21930',
#  'StackedEnsemble_AllModels_1_AutoML_1_20220630_21930',
#  'XGBoost_grid_1_AutoML_1_20220630_21930_model_12',
#  'GBM_3_AutoML_1_20220630_21930',
#  'GBM_grid_1_AutoML_1_20220630_21930_model_17',
#  'StackedEnsemble_AllModels_2_AutoML_1_20220630_21930',
#  'XGBoost_grid_1_AutoML_1_20220630_21930_model_1',
#  'XGBoost_grid_1_AutoML_1_20220630_21930_model_7',
#  'GBM_grid_1_AutoML_1_20220630_21930_model_11',
#  'GBM_2_AutoML_1_20220630_21930',
#  'StackedEnsemble_BestOfFamily_3_AutoML_1_20220630_21930',
#  'GBM_5_AutoML_1_20220630_21930',
#  'StackedEnsemble_BestOfFamily_2_AutoML_1_20220630_21930',
#  'GBM_4_AutoML_1_20220630_21930',
#  'StackedEnsemble_AllModels_4_AutoML_1_20220630_21930',
#  'XGBoost_grid_1_AutoML_1_20220630_21930_model_10',
#  'StackedEnsemble_AllModels_3_AutoML_1_20220630_21930',
#  'XGBoost_grid_1_AutoML_1_20220630_21930_model_2',
# ...

# %%
# Get the "All Models" StackedEnsemble model
SE= h2o.get_model([mid for mid in model_ids if "StackedEnsemble" in mid][0])

# %%
# Get the Stacked Ensemble metalearner model
metalearner = h2o.get_model(SE.metalearner()['name'])
# Out:
# /usr/local/lib/python3.7/dist-packages/h2o/estimators/stackedensemble.py:929: H2ODeprecationWarning: The usage of stacked_ensemble.metalearner()['name'] will be deprecated. Metalearner now returns the metalearner object. If you need to get the 'name' please use stacked_ensemble.metalearner().model_id
#   H2ODeprecationWarning

# %%
# %matplotlib inline
metalearner.std_coef_plot()         #Examine the variable importance of the metalearner (combiner) algorithm in the ensemble.

# %%
SE.params
# Out:
# {'auc_type': {'actual': 'AUTO', 'default': 'AUTO', 'input': 'AUTO'},
#  'base_models': {'actual': [{'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'XGBoost_grid_1_AutoML_1_20220630_21930_model_3',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'GBM_3_AutoML_1_20220630_21930',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'XRT_1_AutoML_1_20220630_21930',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
#      'schema_type': 'Key<Keyed>',
#      'schema_version': 3},
#     'name': 'DRF_1_AutoML_1_20220630_21930',
#     'type': 'Key<Keyed>'},
#    {'URL': None,
#     '__meta': {'schema_name': 'KeyV3',
# ...

# %%
SE
# Out:
# Model Details
# ...
# H2OStackedEnsembleEstimator :  Stacked Ensemble
# Model Key:  StackedEnsemble_BestOfFamily_4_AutoML_1_20220630_21930
#
# No model summary for this model
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 0.11891671742626331
# RMSE: 0.34484303302555397
# MAE: 0.25078568706054216
# RMSLE: 0.1468901798457719
# R^2: 0.9945833328458602
# Mean Residual Deviance: 0.11891671742626331
# Null degrees of freedom: 315
# Residual degrees of freedom: 311
# Null deviance: 6937.417721518995
# Residual deviance: 37.57768270669921
# AIC: 235.9002775012877
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 2.5320433801118853
# RMSE: 1.5912395734495435
# MAE: 1.0810752658857568
# RMSLE: NaN
# R^2: 0.8846651967296899
# Mean Residual Deviance: 2.5320433801118853
# Null degrees of freedom: 315
# Residual degrees of freedom: 311
# Null deviance: 6993.198446664244
# Residual deviance: 800.1257081153558
# ...

# %%
pred=aml.leader.predict(test)
# Out:
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%

# %%
pred.head()
# Out:
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">  7.89757</td></tr>
# <tr><td style="text-align: right;"> 15.4125 </td></tr>
# <tr><td style="text-align: right;"> 14.524  </td></tr>
# <tr><td style="text-align: right;"> 15.976  </td></tr>
# <tr><td style="text-align: right;"> 13.5322 </td></tr>
# <tr><td style="text-align: right;"> 12.8969 </td></tr>
# <tr><td style="text-align: right;">  9.33663</td></tr>
# <tr><td style="text-align: right;">  8.52796</td></tr>
# <tr><td style="text-align: right;">  9.97865</td></tr>
# <tr><td style="text-align: right;">  5.97208</td></tr>
# </tbody>
# </table>

# %%
aml.leader.model_performance(test)
# Out:
# ModelMetricsRegression: xgboost
# ** Reported on test data. **
#
# MSE: 1.6335501673810395
# RMSE: 1.278104130100924
# MAE: 0.864308013191706
# RMSLE: 0.28396500174191774
# Mean Residual Deviance: 1.6335501673810395

# %% [markdown]
# # Summary
#
# ## XGBOOST Regressor with GridSearchCV is the best model for this dataset interms of R2-score, MSE, MAE, RMSE
#
# R2-Score:  0.8264525131210407
#
# Mean Square Error:  3.822648562636821
#
# Root Mean Square Error:  1.9551594724310397
#
# Mean Absolute Error:  1.157339177348397
#
#
# ## For AutoML H2OStackedEnsembleEstimator :  Stacked Ensemble is the best model
# MSE: 0.11891671742626331
#
# RMSE: 0.34484303302555397
#
# MAE: 0.25078568706054216
#
# RMSLE: 0.1468901798457719
#
# R^2: 0.9945833328458602
